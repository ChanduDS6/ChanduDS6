# %% [markdown]
# <a href="https://colab.research.google.com/github/ChanduDS6/ChanduDS6/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
# !pip install --upgrade -q gspread

# %%
import pandas as pd

# %%
data=pd.Series([1,2,3,3,4,5],index=["a","b","c","d","e","f"])

# %%
print(data)
# Out:
# a    1
# b    2
# c    3
# d    3
# e    4
# f    5
# dtype: int64

# %%
data1={
    "Name":["Rahul","Amit","Raj"],
    "Age":[21,20,25],
    "City":["Banglore","Mysuru","Delhi"]

}
df=pd.DataFrame(data1)
print(df)
# Out:
#     Name  Age      City
# 0  Rahul   21  Banglore
# 1   Amit   20    Mysuru
# 2    Raj   25     Delhi

# %%
#single column access
df["Name"]
# Out:
# 0    Rahul
# 1     Amit
# 2      Raj
# Name: Name, dtype: object

# %%
df["Age"]
# Out:
# 0    21
# 1    20
# 2    25
# Name: Age, dtype: int64

# %%
df[["Name","City"]]
# Out:
#     Name      City
# 0  Rahul  Banglore
# 1   Amit    Mysuru
# 2    Raj     Delhi

# %%
df[["Name","City","Age"]]
# Out:
#     Name      City  Age
# 0  Rahul  Banglore   21
# 1   Amit    Mysuru   20
# 2    Raj     Delhi   25

# %%
# row values access with index value
df.loc[0]
# Out:
# Name       Rahul
# Age           21
# City    Banglore
# Name: 0, dtype: object

# %%
df.loc[1]
# Out:
# Name      Amit
# Age         20
# City    Mysuru
# Name: 1, dtype: object

# %%
df.loc[0:1]
# Out:
#     Name  Age      City
# 0  Rahul   21  Banglore
# 1   Amit   20    Mysuru

# %%
df[df["Age"]>20]
# Out:
#     Name  Age      City
# 0  Rahul   21  Banglore
# 2    Raj   25     Delhi

# %%
print(df)
# Out:
#     Name  Age      City
# 0  Rahul   21  Banglore
# 1   Amit   20    Mysuru
# 2    Raj   25     Delhi

# %%
#adding column into dataframe
df["Marks"]=[45,60,70]

# %%
print(df)
# Out:
#     Name  Age      City  Marks
# 0  Rahul   21  Banglore     45
# 1   Amit   20    Mysuru     60
# 2    Raj   25     Delhi     70

# %%
df[df["Age"]==20]
# Out:
#    Name  Age    City  Marks
# 1  Amit   20  Mysuru     60
